# %% [markdown]
# # Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# 4. Discount %
# The attributes which you have to scrape is ticked marked in the below image
# To scrape the data you have to go through following steps:
# 1. Go to flipkart webpage by url https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and
# more” is written and click the search icon
# 3. after that you will reach to a webpage having a lot of sunglasses. From this page
# you can scrap the required data as usual.
# 4. after scraping data from the first page, go to the “Next” Button at the bottom of
# the page , then click on it
# 5. Now scrape data from this page as usual
# 6. repeat this until you get data for 100 sunglasses.
# Note that all of the above steps have to be done by coding only and not manually.

# %%
import selenium
from selenium import webdriver

# %%
driver=webdriver.Chrome("chromedriver1.exe")
url="https://www.flipkart.com"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("//input[@title='Search for products, brands and more']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a1116f549b4ee16b2ebd13fc404b9594", element="3a3bea75-e64a-4709-a62e-8e04763d58d4")>

# %%
search_job.send_keys("sunglasses")

# %%
search_button=("//button[@class='L0Z3Pu']")
search_button.click()

# %%
company_name1=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
company_name1
company_name2=[]

for i in company_name1:
    company_name2.append(i.text)
company_name2

Product_des1=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
Product_des1
Product_des2=[]

for i in Product_des1:
    Product_des2.append(i.text)
Product_des2

Price1=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
Price1
Price2=[]

for i in Price1:
    Price2.append(i.text)
Price2

Discount1=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
Discount1
Discount2=[]

for i in Discount1:
    Discount2.append(i.text)
Discount2
# Out:
#                 Brand                                        Product-Des  \
# 0              GANSTA              UV Protection Aviator Sunglasses (57)
# 1        Singco India  Mirrored, UV Protection, Riding Glasses, Other...
# 2           Elligator                UV Protection Round Sunglasses (54)
# 3   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 4      kingsunglasses  Mirrored, UV Protection Wayfarer Sunglasses (F...
# 5      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 6              PIRASO              UV Protection Aviator Sunglasses (54)
# 7           ROYAL SON     Polarized, UV Protection Round Sunglasses (49)
# 8            Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 9      kingsunglasses                UV Protection Round Sunglasses (54)
# 10     ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)
# 11            Villain             Others Wayfarer Sunglasses (Free Size)
# 12  SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 13             PIRASO              UV Protection Aviator Sunglasses (54)
# 14             SUNBEE  UV Protection, Polarized, Mirrored Wayfarer Su...
# 15             AISLIN       UV Protection, Gradient Oval Sunglasses (58)
# 16             PIRASO              UV Protection Aviator Sunglasses (54)
# 17          ROYAL SON          UV Protection Rectangular Sunglasses (58)
# 18  SHAAH COLLECTIONS         UV Protection Round Sunglasses (Free Size)
# 19          ROYAL SON   UV Protection, Polarized Aviator Sunglasses (60)
# 20           Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 21            DEIXELS  UV Protection Aviator, Wayfarer Sunglasses (Fr...
# 22            OCCARIO                       Others Round Sunglasses (52)
# 23             Sewell  Mirrored, Night Vision, UV Protection, Riding ...
# 24         PHENOMENAL  UV Protection Retro Square Sunglasses (Free Size)
# 25     ROZZETTA CRAFT  UV Protection, Riding Glasses Rectangular Sung...
# 26           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 27              agera          UV Protection Rectangular Sunglasses (57)
# 28     ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...
# 29          New Specs  Mirrored, UV Protection, Riding Glasses, Other...
# 30       Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)
# 31              agera                   Gradient Aviator Sunglasses (55)
# 32               hipe  UV Protection, Gradient, Mirrored, Riding Glas...
# 33          Elligator                UV Protection Round Sunglasses (55)
# 34          Rich Club  UV Protection, Mirrored, Gradient Round Sungla...
# 35       Singco India  Riding Glasses, UV Protection, Others Aviator ...
# 36          ROYAL SON                   Mirrored Aviator Sunglasses (55)
# 37             SUNBEE  UV Protection, Polarized, Mirrored Retro Squar...
# 38              povty      UV Protection Wayfarer Sunglasses (Free Size)
# 39             GANSTA  UV Protection, Gradient, Riding Glasses Wayfar...
#
#    Price Discount
# 0   ₹284  85% off
# 1   ₹331  83% off
# 2   ₹295  88% off
# 3   ₹198  88% off
# 4   ₹284  89% off
# 5   ₹404  79% off
# 6   ₹237  85% off
# 7   ₹664  66% off
# 8   ₹509  36% off
# 9   ₹213  80% off
# 10  ₹499  77% off
# 11  ₹599  40% off
# 12  ₹215  78% off
# 13  ₹237  85% off
# 14  ₹265  73% off
# 15  ₹498  67% off
# 16  ₹237  85% off
# 17  ₹474  68% off
# 18  ₹331  80% off
# 19  ₹711  64% off
# 20  ₹520  34% off
# 21  ₹202  83% off
# 22  ₹179  69% off
# 23  ₹236  84% off
# 24  ₹399  80% off
# 25  ₹449  79% off
# 26  ₹859   4% off
# 27  ₹257  80% off
# 28  ₹449  77% off
# 29  ₹299  81% off
# 30  ₹246  83% off
# 31  ₹236  79% off
# 32  ₹209  79% off
# 33  ₹266  86% off
# 34  ₹215  73% off
# 35  ₹232  84% off
# 36  ₹379  74% off
# 37  ₹314  75% off
# 38  ₹349  65% off
# 39  ₹341  82% off

# %%
second_page=driver.find_element_by_xpath('//nav/a[@class="_1LKTO3" ]/span[text() = "Next"]')
second_page1=second_page.click()

# %%
company_name3=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
company_name3
company_name4=[]

for i in company_name3:
    company_name4.append(i.text)
company_name4

Product_des3=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
Product_des3
Product_des4=[]

for i in Product_des3:
    Product_des4.append(i.text)
Product_des4

Price3=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
Price3
Price4=[]

for i in Price3:
    Price4.append(i.text)
Price4

Discount3=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
Discount3
Discount4=[]

for i in Discount3:
    Discount4.append(i.text)
Discount4
# Out:
#              Brand                                        Product-Des   Price  \
# 0           PIRASO            UV Protection Butterfly Sunglasses (65)    ₹426
# 1   kingsunglasses      UV Protection, Mirrored Round Sunglasses (54)    ₹236
# 2   kingsunglasses          UV Protection Rectangular Sunglasses (55)    ₹199
# 3        ROYAL SON     Polarized, UV Protection Round Sunglasses (49)    ₹664
# 4           HIPPON             UV Protection Wayfarer Sunglasses (55)    ₹257
# 5       PHENOMENAL  UV Protection, Mirrored Retro Square Sunglasse...    ₹399
# 6     Singco India  Riding Glasses, Others, UV Protection Wrap-aro...    ₹293
# 7     Singco India  Mirrored, UV Protection, Riding Glasses, Other...    ₹331
# 8           Singco                   Mirrored Aviator Sunglasses (53)    ₹239
# 9           PIRASO              UV Protection Aviator Sunglasses (58)    ₹399
# 10  kingsunglasses  Mirrored, UV Protection Wayfarer Sunglasses (F...    ₹284
# 11         Villain             Others Wayfarer Sunglasses (Free Size)    ₹599
# 12       Elligator                     Mirrored Round Sunglasses (53)    ₹312
# 13          GANSTA  Night Vision, Riding Glasses Wayfarer Sunglass...    ₹209
# 14        Fastrack             UV Protection Wayfarer Sunglasses (55)    ₹610
# 15          AISLIN       UV Protection, Gradient Oval Sunglasses (58)    ₹498
# 16      PHENOMENAL                UV Protection Round Sunglasses (53)    ₹295
# 17    Singco India       UV Protection Aviator Sunglasses (Free Size)    ₹334
# 18        Fastrack             UV Protection Wayfarer Sunglasses (56)    ₹369
# 19       ROYAL SON   UV Protection, Polarized Aviator Sunglasses (60)    ₹711
# 20          GANSTA              UV Protection Aviator Sunglasses (57)    ₹284
# 21  kingsunglasses         UV Protection Round Sunglasses (Free Size)    ₹331
# 22        Fastrack              UV Protection Aviator Sunglasses (58)  ₹1,239
# 23           agera          UV Protection Rectangular Sunglasses (57)    ₹257
# 24    Silver Kartz                 UV Protection Oval Sunglasses (56)    ₹284
# 25          GANSTA    UV Protection, Gradient Aviator Sunglasses (55)    ₹289
# 26          GANSTA  UV Protection, Night Vision, Riding Glasses Av...    ₹295
# 27           agera                   Gradient Aviator Sunglasses (55)    ₹236
# 28  kingsunglasses  UV Protection, Mirrored Round Sunglasses (Free...    ₹260
# 29      PHENOMENAL    UV Protection Clubmaster Sunglasses (Free Size)    ₹319
# 30       Elligator  UV Protection, Riding Glasses Rectangular, Ret...    ₹398
# 31          Sewell  Mirrored, Night Vision, UV Protection, Riding ...    ₹236
# 32         DEIXELS  Polarized, UV Protection, Riding Glasses Wayfa...    ₹236
# 33          SUNBEE  UV Protection, Polarized, Mirrored Wayfarer Su...    ₹314
# 34        Fastrack             UV Protection Wayfarer Sunglasses (57)    ₹499
# 35    Singco India  Riding Glasses, UV Protection, Others Aviator ...    ₹232
# 36            hipe  UV Protection, Night Vision, Riding Glasses, G...    ₹210
# 37            hipe  UV Protection, Night Vision, Gradient, Mirrore...    ₹210
# 38       Rich Club        UV Protection, Others Round Sunglasses (48)    ₹299
# 39          GANSTA  UV Protection, Gradient, Riding Glasses Wayfar...    ₹341
#
#    Discount
# 0   83% off
# 1   80% off
# 2   84% off
# 3   66% off
# 4   78% off
# 5   80% off
# 6   82% off
# 7   83% off
# 8   76% off
# 9   84% off
# 10  89% off
# 11  40% off
# 12  87% off
# 13  88% off
# 14  23% off
# 15  67% off
# 16  87% off
# 17  72% off
# 18  58% off
# 19  64% off
# 20  85% off
# 21  79% off
# 22   4% off
# 23  80% off
# 24  76% off
# 25  85% off
# 26  85% off
# 27  79% off
# 28  84% off
# 29  84% off
# 30  73% off
# 31  84% off
# 32  60% off
# 33  75% off
# 34  37% off
# 35  84% off
# 36  83% off
# 37  78% off
# 38  62% off
# 39  82% off

# %%
company_name5=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
company_name5
company_name6=[]

for i in company_name5:
    company_name6.append(i.text)
company_name6

Product_des5=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
Product_des5
Product_des6=[]

for i in Product_des5:
    Product_des6.append(i.text)
Product_des6

Price5=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
Price5
Price6=[]

for i in Price5:
    Price6.append(i.text)
Price5

Discount5=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
Discount5
Discount6=[]

for i in Discount5:
    Discount6.append(i.text)
Discount6


company_name=company_name2+company_name4+company_name6
Product_des=Product_des2+Product_des4+Product_des6
Price=Price2+Price4+Price6
Discount=Discount2+Discount4+Discount6

import pandas as pd
Glasses_F=pd.DataFrame({})
Glasses_F["Brand"]=company_name[0:100]
Glasses_F["Product-Des"]=Product_des[0:100]
Glasses_F["Price"]=Price[0:100]
Glasses_F["Discount"]=Discount[0:100]
Glasses_F
# Out:
#                 Brand                                        Product-Des  \
# 0              GANSTA              UV Protection Aviator Sunglasses (57)
# 1        Singco India  Mirrored, UV Protection, Riding Glasses, Other...
# 2           Elligator                UV Protection Round Sunglasses (54)
# 3   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 4      kingsunglasses  Mirrored, UV Protection Wayfarer Sunglasses (F...
# ..                ...                                                ...
# 95             AISLIN       UV Protection, Gradient Oval Sunglasses (58)
# 96         PHENOMENAL                UV Protection Round Sunglasses (53)
# 97       Singco India       UV Protection Aviator Sunglasses (Free Size)
# 98           Fastrack             UV Protection Wayfarer Sunglasses (56)
# 99          ROYAL SON   UV Protection, Polarized Aviator Sunglasses (60)
#
#    Price Discount
# 0   ₹284  85% off
# 1   ₹331  83% off
# 2   ₹295  88% off
# 3   ₹198  88% off
# 4   ₹284  89% off
# ..   ...      ...
# 95  ₹498  67% off
# 96  ₹295  87% off
# 97  ₹334  72% off
# 98  ₹369  58% off
# 99  ₹711  64% off
#
# [100 rows x 4 columns]
